# %% [markdown]
# Import libraries

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Define keywords to search for and useful functions

# %%
input_file = './Test-Data/Odoo-Application/Logs/odoo.log'
input_file_2 = ""

def get_timestamp(message):
    return 'capture-' + message[5:7] + '-' + message[8:10] + '-' + message[2:4] + '-' + message[11:16]


def find_image(line):
    prefix = get_timestamp(line)
    return glob.glob('./screenshots/' + prefix + '*.*')


def show_image(file_path):
    img = mpimg.imread(file_path)
    imgplot = plt.imshow(img)
    plt.show()

# %% [markdown]
# Testing

# %%
key_words = ['message_post', 'name_create']

file_handle = open(input_file, 'r')
file_content = file_handle.readlines()

for line in file_content:
    if line.find(key_words[0]) > 0:
        print('Found ', line)
        found_file_list = find_image(line)
        if len(found_file_list) > 0:      
            show_image(found_file_list[0])
        else:
            print('No evidence (screenshot) found.\n')

file_handle.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8e8b58feefbd> in <module>()
#       1 key_words = ['message_post', 'name_create']
#       2
# ----> 3 file_handle = open(input_file, 'r')
#       4 file_content = file_handle.readlines()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: './Test-Data/Odoo-Application/Logs/odoo.log'
