# %% [markdown]
# Import libraries

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Define keywords to search for and useful functions

# %%
input_file = './Test-Data/Odoo-Application/Logs/odoo.log'

def get_timestamp(message):
    return 'capture-' + message[5:7] + '-' + message[8:10] + '-' + message[2:4] + '-' + message[11:16]


def find_image(line):
    prefix = get_timestamp(line)
    return glob.glob('./screenshots/' + prefix + '*.*')


def show_image(file_path):
    img = mpimg.imread(file_path)
    imgplot = plt.imshow(img)
    plt.show()

# %% [markdown]
# Testing

# %%
key_words = ['message_post', 'name_create']

file_handle = open(input_file, 'r')
file_content = file_handle.readlines()

for line in file_content:
    if line.find(key_words[0]) > 0:
        print('Found ', line)
        found_file_list = find_image(line)
        if len(found_file_list) > 0:      
            show_image(found_file_list[0])
        else:
            print('No evidence (screenshot) found.\n')

file_handle.close()
# Out:
# Found  2018-01-07 17:37:05,543 4338 INFO DCU_Experiment_1 werkzeug: 192.168.0.116 - - [07/Jan/2018 17:37:05] "POST /web/dataset/call_kw/project.task/name_create HTTP/1.1" 200 -
# Found  2018-01-07 17:41:18,595 4338 INFO DCU_Experiment_1 werkzeug: 192.168.0.116 - - [07/Jan/2018 17:41:18] "POST /web/dataset/call_kw/project.task/name_create HTTP/1.1" 200 -
# Found  2018-01-07 17:49:43,251 4338 INFO DCU_Experiment_1 werkzeug: 192.168.0.116 - - [07/Jan/2018 17:49:43] "POST /web/dataset/call_kw/project.task.type/name_create HTTP/1.1" 200 -
# Found  2018-01-07 17:51:21,540 4338 INFO DCU_Experiment_1 werkzeug: 192.168.0.116 - - [07/Jan/2018 17:51:21] "POST /web/dataset/call_kw/project.task/name_create HTTP/1.1" 200 -
# Found  2018-01-09 15:03:23,562 2557 INFO DCU_Experiment_1 werkzeug: 127.0.0.1 - - [09/Jan/2018 15:03:23] "POST /web/dataset/call_kw/project.task.type/name_create HTTP/1.1" 200 -
# Found  2018-01-09 15:04:47,423 2557 INFO DCU_Experiment_1 werkzeug: 192.168.0.116 - - [09/Jan/2018 15:04:47] "POST /web/dataset/call_kw/project.task/name_create HTTP/1.1" 200 -
# Found  2018-01-09 15:05:14,432 2557 INFO DCU_Experiment_1 werkzeug: 192.168.0.116 - - [09/Jan/2018 15:05:14] "POST /web/dataset/call_kw/project.task/name_create HTTP/1.1" 200 -
# Found  2018-01-09 15:05:35,217 2557 INFO DCU_Experiment_1 werkzeug: 192.168.0.116 - - [09/Jan/2018 15:05:35] "POST /web/dataset/call_kw/project.task/name_create HTTP/1.1" 200 -
# Found  2018-01-09 15:05:45,536 2557 INFO DCU_Experiment_1 werkzeug: 192.168.0.116 - - [09/Jan/2018 15:05:45] "POST /web/dataset/call_kw/project.task/name_create HTTP/1.1" 200 -
